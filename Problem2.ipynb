# %% [markdown]
# # Question 2
#
# The second question that I pose on the cereal is to understand how are the consumer report ratings affected by the different nutrition contents? How is the highest rated product nutritional contents look like compared to the lowest rated nutritional products? What does the consumer report ratings tell us considering the nutritional contents of the cereal? Do consumers prefer healthy or tasty but unhealthy cereal based on the consumer report ratings?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
df = pd.read_csv("cereal.csv")
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.groupby(["shelf"])

# %%
data = df.head(15)
data.plot(x="name", y=["protein", "fat", "fiber", "sugars"], kind="bar", figsize=(15, 15),
          title="Highest Rated Products Nutrition Facts", xlabel="Cereal Product Name", rot=45)
# Out:
# <AxesSubplot:title={'center':'Highest Rated Products Nutrition Facts'}, xlabel='Cereal Product Name'>

# %%
data = df.tail(15)
data.plot(x="name", y=["protein", "fat", "fiber", "sugars"], kind="bar", figsize=(15, 15),
          title="Lowest Rated Products Nutrition Facts", xlabel="Cereal Product Name", rot=45)
# Out:
# <AxesSubplot:title={'center':'Lowest Rated Products Nutrition Facts'}, xlabel='Cereal Product Name'>

# %%
data = df.head(15)
data.plot(x="name", y=["calories", "carbo", "sodium", "potass", "vitamins"], kind="bar", figsize=(15, 15),
          title="Highest Rated Products Nutrition Facts", xlabel="Cereal Product Name", rot=45)
# Out:
# <AxesSubplot:title={'center':'Highest Rated Products Nutrition Facts'}, xlabel='Cereal Product Name'>

# %%
data = df.tail(15)
data.plot(x="name", y=["calories", "carbo", "sodium", "potass", "vitamins"], kind="bar", figsize=(15, 15),
          title="Lowest Rated Products Nutrition Facts", xlabel="Cereal Product Name", rot=45)
# Out:
# <AxesSubplot:title={'center':'Lowest Rated Products Nutrition Facts'}, xlabel='Cereal Product Name'>
